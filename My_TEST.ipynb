# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#   Using cached pip-22.1.2-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\User\\AppData\\Local\\Temp\\pip-uninstall-mb90dh4v\\pip3.exe'
# Consider using the `--user` option or check the permissions.

# %%
# 220513 Test
# KNU_Final_Project
# IMG Labeling csv file

import pandas as pd

# %%
label1 = pd.read_csv('D:\Final_Project\Data\Img_label\labels_0_잡곡밥.csv')

# %%
label1
# Out:
#      잡곡밥   22    2  588  473  Img_076_0000.JPG  640  480
# 0    잡곡밥   61   74  375  271  Img_076_0001.jpg  493  413
# 1    잡곡밥   12   65  728  426  Img_076_0002.jpg  740  493
# 2    잡곡밥   69   18  553  538  Img_076_0003.jpg  900  596
# 3    잡곡밥   10   37  474  315  Img_076_0004.JPG  500  375
# 4    잡곡밥  122   62  273  182  Img_076_0005.jpg  601  401
# ..   ...  ...  ...  ...  ...               ...  ...  ...
# 233  잡곡밥   59   57  460  398  Img_076_0244.jpg  600  467
# 234  잡곡밥  147  100  599  487  Img_076_0245.jpg  900  675
# 235  잡곡밥   41  170  341  300  Img_076_0247.jpg  728  485
# 236  잡곡밥  246  311  356  329  Img_076_0253.jpg  640  640
# 237  잡곡밥   62  195  233  207  Img_076_0254.jpg  740  514
#
# [238 rows x 8 columns]

# %%
aaa = '''
    N_CAROT
    '''
aaa
# Out:
# '\n    N_CAROT,BS13,N_INTK,N_EN,LQ_5EQL,BE3_85,N_WATER,HE_HT,N_CHOL,N_NA,N_PROT,\n    BP7,LQ_2EQL,HE_DBP,LQ_1EQL,BE3_81,N_SFA,ID,HE_RPLS,N_SUGAR,SM_PRESNT,L_BR_FQ,LQ4_00\n    '

# %%
# 선택
<div class="row align-items-center mt-4">
                      <div class="col form-group">
                          <label>최근 7일 동안, 공공장소의 실내에서 다른사람이 피우는 담배연기를 맡은 적이 있습니까?</label>
                          <select name="BS13" id="" class="form-control custom select">
                          <option value="1">예</option>
                          <option value="2">아니오</option>
                          </select>
                        </div>
                    </div>

# 입력
<div class="row align-items-center mt-4">
                      <div class="col">
                          <label>1일 베타카로틴 섭취량(μg)</label>
                          <input name="N_CAROT" type="text" class="form-control" placeholder="숫자 입력(μg)">
                        </div>
                    </div>
